# %%
import pandas as pd
import numpy as np
import os

from collections import Counter
import seaborn as sns
import matplotlib.pyplot as plt

# %%
os.chdir('/shared/0/projects/research-jam-summer-2024/')

# %%
base_dir = 'data/english_only/prompting_results_clean/with_metrics/' #experiment 1
#base_dir = 'data/english_only/100k_results/with_metrics' #experiment 2

# %%
for f in os.listdir(base_dir):
    if f.startswith('wildchat_subset_en_2k_prompting') and not f.endswith('_end.jsonl') and not f.endswith('lexical.jsonl'):
        print(f)
    else: 
        print('NOT:',f)
# Out:
# wildchat_subset_en_2k_prompting_Qwen2-72B-Instruct.jsonl
# NOT: llama3.1_70B_100_sample_with_metrics.jsonl
# NOT: wildchat_subset_en_2k_prompting_Meta-Llama-3.1-70B-Instruct_end.jsonl
# wildchat_subset_en_2k_prompting_Mixtral-8x7B-Instruct-v0.1.jsonl
# NOT: mixtral_test.jsonl
# NOT: wildchat_subset_en_2k_prompting_Qwen2-72B-Instruct_end.jsonl
# wildchat_subset_en_2k_prompting_Phi-3-medium-4k-instruct.jsonl
# NOT: wildchat_subset_en_2k_prompting_Phi-3-medium-4k-instruct_end.jsonl
# NOT: wildchat_subset_en_2k_prompting_Mistral-7B-Instruct-v0.3-lexical.jsonl
# NOT: llama_3.1-70B_100_sample.jsonl
# wildchat_subset_en_2k_prompting_Mistral-7B-Instruct-v0.3.jsonl
# NOT: wildchat_subset_en_2k_prompting_Meta-Llama-3.1-8B-Instruct_end.jsonl
# wildchat_subset_en_2k_prompting_Meta-Llama-3.1-8B-Instruct.jsonl
# NOT: wildchat_subset_en_2k_prompting_Mixtral-8x7B-Instruct-v0.1_end.jsonl
# NOT: mixtral_100_sample_with_metrics.jsonl
# NOT: mixtral_100_sample.jsonl
# NOT: wildchat_subset_en_2k_prompting_Mistral-7B-Instruct-v0.3_end.jsonl
# wildchat_subset_en_2k_prompting_Meta-Llama-3.1-70B-Instruct.jsonl

# %%
metrics.to_json('data/wildchat_subset_en_2k_prompting_all_normalized_metrics.jsonl', orient='records', lines=True)

# %%
def make_df(f):
    df = pd.read_json(base_dir+f, orient='records', lines=True)
    df['model'] = f
    return df

# %%
metrics = []
for f in os.listdir(base_dir):
    if f.startswith('wildchat_subset_en_2k_prompting') and not f.endswith('_end.jsonl') and not f.endswith('lexical.jsonl'):
        metrics.append(make_df(f))
metrics = pd.concat(metrics).reset_index(drop=True)
metrics['metric_perplexity'] = (1 - 1/metrics['llm_perplexity']) - (1 - 1/metrics['human_perplexity'])

# %%
metrics['human_readability'] = metrics['human_readability'].fillna(0)
metrics['human_readability'][metrics['human_readability']<0] = 1
metrics['llm_readability'] = metrics['llm_readability'].fillna(0)
metrics['llm_readability'][metrics['llm_readability']<0] = 1
metrics['metric_readability'] = metrics['metric_readability'].fillna(0)
metrics['metric_readability'] = metrics['llm_readability'] - metrics['human_readability']
# Out:
# /tmp/ipykernel_2438089/1398955784.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   metrics['human_readability'][metrics['human_readability']<0] = 1
# /tmp/ipykernel_2438089/1398955784.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metrics['human_readability'][metrics['human_readability']<0] = 1
# /tmp/ipykernel_2438089/1398955784.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   metrics['llm_readability'][metrics['llm_readability']<0] = 1
# /tmp/ipykernel_2438089/1398955784.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metrics['llm_readability'][metrics['llm_readability']<0] = 1

# %%
def capital_rate(text):
    # count number of capital letters
    capital_count = sum(1 for char in text if char.isupper())

    # count number of aplhabet letters (i.e., letters that can be capitalized)
    total_letter_count = sum(1 for char in text if char.isalpha())

    if total_letter_count > 0:
        return capital_count / total_letter_count
    else:
        return np.nan

# calculate capital rate for human and ai
metrics['human_capitalization'] = metrics['human_turn_3'].apply(capital_rate)
metrics['llm_capitalization'] = metrics['llm_turn_3'].apply(capital_rate)
metrics['metric_capitalization'] = metrics['llm_capitalization'] - metrics['human_capitalization']

# %%
import re
metrics = metrics[metrics.llm_turn_3.apply(lambda x: re.sub('\s|\n|\r','',x)!='')]

# %%
def get_word_length(utterance):
    return np.mean([len(word) for word in utterance.split()])
metrics['human_log_word_length'] = np.log(metrics.human_turn_3.apply(get_word_length))
metrics['llm_log_word_length'] = np.log(metrics.llm_turn_3.apply(get_word_length))
metrics['metric_log_word_length'] = metrics['llm_log_word_length'] - metrics['human_log_word_length']

# %%
from copy import deepcopy
metrics_orig = deepcopy(metrics)

# %%
metrics.shape
# Out:
# (194861, 71)

# %%
Counter(metrics.human_turn_1.isna())
# Out:
# Counter({False: 194861})

# %%
Counter(metrics[metrics.human_turn_1.isna()].model)
# Out:
# Counter()

# %%
metrics = metrics[~metrics.human_turn_1.isna()]

# %%
[c for c in metrics.columns if c.startswith('metric')]
# Out:
# ['metric_perplexity',
#  'metric_factuality',
#  'metric_subjectivity',
#  'metric_bleu',
#  'metric_liwc',
#  'metric_luar',
#  'metric_politeness',
#  'metric_readability',
#  'metric_rouge',
#  'metric_sentiment',
#  'metric_toxicity',
#  'metric_capitalization',
#  'metric_contract_count',
#  'metric_end',
#  'metric_formality',
#  'metric_log_word_count',
#  'metric_pos',
#  'metric_punctuation',
#  'metric_sbert',
#  'metric_topic',
#  'metric_typo',
#  'metric_word_length',
#  'metric_log_word_length']

# %%
def normalize(x, method = 'minmax', center = True, pos_scale = True, remove_outlier='none'):
    x_norm = x
    
    if method == 'zscore':
        if remove_outlier == 'IQR':
            q1 = np.percentile(x_norm, 25)
            q3 = np.percentile(x_norm, 75)
            iqr = q3 - q1
            lower = q1 - 1.5*iqr
            upper = q3 + 1.5*iqr
            x_norm[x_norm < lower] = lower
            x_norm[x_norm > upper] = upper
        
        if center: x_norm = x_norm - np.mean(x_norm)
        x_norm = x_norm / np.std(x_norm)
        
    if method == 'minmax':
#         if remove_outlier == 'percentile_99':
#             quantile = [i/len(x_norm) for i in sorted(range(len(x_norm)), key=x_norm.__getitem__)]
#             x_norm = [np.percentile(x_norm, 0.5) if quantile[i]<0.005 
#                       else np.percentile(x_norm, 99.5) if quantile[i]>0.995 
#                       else x_norm[i] for i in range(len(x_norm))]

        min_val = min(x_norm)
        max_val = max(x_norm)
        if pos_scale: x_norm = (x_norm - min_val)/(max_val - min_val)
        else: x_norm = 2*(x_norm - min_val)/(max_val - min_val) - 1
            
#         if remove_outlier == 'percentile_99':
#             x_norm = x_norm * 0.99 + 0.005
#             x_norm = [quantile[i] if quantile[i]<0.005 or quantile[i]>0.995 
#                       else x_norm[i] for i in range(len(x_norm))]
            
    return x_norm

# %%
#min-max normalize cosine similarity (-1 to 1 scale)
for c in ['metric_sbert','metric_luar']:
    sns.histplot(metrics[c])
    plt.show()
    metrics[c] = (metrics[c]+1)/2
    sns.histplot(metrics[c])
    plt.show()

# %%
#min-max normalize count data
needs_normalization = ['metric_log_word_count', 'metric_log_word_length']
for c in needs_normalization:
    sns.histplot(metrics[c])
    plt.show()
    sns.histplot(metrics[c].abs())
    plt.show()
    metrics[c] = 1-normalize(metrics[c].abs())
    sns.histplot(metrics[c])
    plt.show()

# %%
# Turn RMSE to similarity with 1-x
for c in ['metric_punctuation']:
    sns.histplot(metrics[c])
    plt.show()
    metrics[c] = 1 - metrics[c]
    sns.histplot(metrics[c])
    plt.show()

# %%
needs_abs_diff = ['metric_perplexity',
                  'metric_contract_count',
                  'metric_typo',
                  'metric_capitalization',
                  #'metric_grammar',
                  'metric_sentiment',
                  'metric_politeness',
                  'metric_formality',
                  'metric_toxicity',
                  'metric_readability',
                  'metric_factuality',
                  'metric_subjectivity',
                 ]

for c in needs_abs_diff:
    if c=='metric_toxicity':
        metrics[c] = 1 - np.abs(metrics[c])
    else:
        sns.histplot(metrics[c])
        plt.show()
        metrics[c] = 1 - np.abs(metrics[c])
        sns.histplot(metrics[c])
        plt.show()

# %%
'metric_end'

lexical = ['metric_log_word_count',
           'metric_log_word_length',
           'metric_perplexity',
           'metric_contract_count',
           'metric_typo',
          ]

syntactic = [#'metric_grammar',
             'metric_capitalization',
             'metric_punctuation',
             'metric_pos',
             #'metric_constituency_parse',
            ]

semantic = ['metric_sbert',
            'metric_rouge',
            #'metric_bleu',
            'metric_liwc',
            'metric_topic',
           ]

style = ['metric_sentiment',
         'metric_politeness',
         'metric_formality',
         'metric_toxicity',
         'metric_factuality',
         'metric_readability',
         'metric_subjectivity',
         'metric_luar',
        ]


all_metrics = deepcopy(lexical)
all_metrics.extend(syntactic)
all_metrics.extend(semantic)
all_metrics.extend(style)

# %%
sns.heatmap(metrics[all_metrics].corr())
# Out:
# <Axes: >

# %%
metrics[lexical]
# Out:
#         metric_log_word_count  metric_log_word_length  metric_perplexity  \
# 0                    0.859130                0.992529           0.982700
# 1                    0.718513                0.960377           0.979476
# 2                    0.955117                0.998376           0.991980
# 3                    0.935514                0.988803           0.995132
# 4                    0.834125                0.922464           0.905029
# ...                       ...                     ...                ...
# 194861               0.878297                0.985442           0.984707
# 194862               0.722617                0.971366           0.964535
# 194863               0.922154                0.977337           0.953607
# 194864               0.638765                0.820833           0.968858
# 194865               0.679654                0.993596           0.931897
#
#         metric_contract_count  metric_capitalization  metric_typo
# 0                    1.000000               0.999445     0.951087
# 1                    0.954545               0.962457     0.863636
# 2                    0.950000               0.986891     0.957143
# 3                    0.972973               0.998369     0.929730
# 4                    1.000000               0.928234     0.626707
# ...                       ...                    ...          ...
# 194861               1.000000               0.984717     0.918018
# 194862               1.000000               0.947964     0.805556
# 194863               1.000000               0.987903     0.707249
# 194864               1.000000               0.977446     0.733333
# 194865               1.000000               0.988219     0.959565
#
# [194861 rows x 6 columns]

# %%
for c in lexical:
    sns.histplot(metrics[c])
    plt.show()

metrics['agg_lexical'] = metrics[lexical].apply(lambda x: x.mean(), axis=1)
sns.histplot(metrics['agg_lexical'])
plt.show()

# %%
sns.heatmap(metrics[[c for c in metrics.columns if c in lexical or c=='agg_lexical']].corr())
# Out:
# <Axes: >

# %%
metrics[syntactic]
# Out:
#         metric_punctuation  metric_pos
# 0                 0.991985    0.667197
# 1                 0.997008    0.644471
# 2                 0.996470    0.706228
# 3                 0.997840    0.743826
# 4                 0.994821    0.729553
# ...                    ...         ...
# 194861            0.996727    0.821385
# 194862            0.993750    0.424810
# 194863            0.991270    0.558388
# 194864            0.986368    0.408165
# 194865            0.997233    0.792102
#
# [194861 rows x 2 columns]

# %%
for c in syntactic:
    sns.histplot(metrics[c])
    plt.show()

metrics['agg_syntactic'] = metrics[syntactic].apply(lambda x: x.mean(), axis=1)
sns.histplot(metrics['agg_syntactic'])
plt.show()

# %%
sns.heatmap(metrics[[c for c in metrics.columns if c in syntactic or c=='agg_syntactic']].corr())
# Out:
# <Axes: >

# %%
metrics[semantic]
# Out:
#         metric_sbert  metric_rouge  metric_liwc  metric_topic
# 0           0.571125      0.064516     0.380145      0.837469
# 1           0.518482      0.081081     0.465156      0.876667
# 2           0.575227      0.166667     0.481949      0.837524
# 3           0.869768      0.123711     0.517929      0.835652
# 4           0.567366      0.000000          NaN      0.684453
# ...              ...           ...          ...           ...
# 194861      0.550338      0.078652     0.612926      0.874644
# 194862      0.742299      0.024691          NaN      0.885212
# 194863      0.507412      0.013514     0.373833      0.463205
# 194864      0.564339      0.000000          NaN      0.841749
# 194865      0.858194      0.146179     0.573508      0.379485
#
# [194861 rows x 4 columns]

# %%
for c in semantic:
    sns.histplot(metrics[c])
    plt.show()

metrics['agg_semantic'] = metrics[semantic].apply(lambda x: x.mean(), axis=1)
sns.histplot(metrics['agg_semantic'])
plt.show()

# %%
sns.heatmap(metrics[[c for c in metrics.columns if c in semantic or c=='agg_semantic']].corr())
# Out:
# <Axes: >

# %%
metrics[style]
# Out:
#         metric_sentiment  metric_politeness  metric_formality  \
# 0               0.782249           0.132324          0.907578
# 1               0.742125           0.989906          0.982106
# 2               0.712950           0.612812          0.548469
# 3               0.737371           0.766473          0.989835
# 4               0.776054           0.486047          0.994945
# ...                  ...                ...               ...
# 194861          0.762222           0.902118          0.946579
# 194862          0.714026           0.441842          0.992561
# 194863          0.663201           0.656125          0.997936
# 194864          0.711367           0.301095          0.990740
# 194865          0.968423           0.600921          0.998043
#
#         metric_toxicity  metric_factuality  metric_readability  \
# 0              0.000852           0.998623            0.190545
# 1              0.000002           0.993048            0.374818
# 2              0.000006           0.996001            0.967636
# 3              0.000012           0.794748            0.759818
# 4              0.000029           0.577418            0.037636
# ...                 ...                ...                 ...
# 194861         0.000037           0.826862            0.911091
# 194862         0.000017           0.992937            0.362455
# 194863         0.018151           0.761534            0.746273
# 194864         0.000018           0.980892            0.111818
# 194865         0.000008           0.892294            0.910455
#
#         metric_subjectivity  metric_luar
# 0                  0.950000     0.641792
# 1                  0.275000     0.728721
# 2                  0.897727     0.735985
# 3                  0.960000     0.766536
# 4                  0.481250     0.837766
# ...                     ...          ...
# 194861             0.566667     0.759456
# 194862             0.450000     0.714786
# 194863             0.852520     0.714306
# 194864             1.000000     0.705647
# 194865             0.933683     0.833758
#
# [194861 rows x 8 columns]

# %%
for c in style:
    if c!='metric_toxicity':
        sns.histplot(metrics[c])
        plt.show()

metrics['agg_style'] = metrics[style].apply(lambda x: x.mean(), axis=1)
sns.histplot(metrics['agg_style'])
plt.show()

# %%
sns.heatmap(metrics[[c for c in metrics.columns if c in style or c=='agg_style']].corr())
# Out:
# <Axes: >

# %%
sns.heatmap(metrics[[c for c in metrics.columns if c.startswith('agg_')]].corr())
# Out:
# <Axes: >
